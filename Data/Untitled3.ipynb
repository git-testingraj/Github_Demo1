# %%
import pandas as pd
import oracledb
from sqlalchemy import create_engine
oracledb.init_oracle_client(lib_dir=r"C:\oraclexe\app\oracle\instantclient_19_29")
# Connect to Oracle Database

#connection = oracledb.connect(
# user="ETL_Automation",
# password="ETL_Automation",
# dsn="localhost:1521/xe"
#)

oracle_engine = create_engine("oracle+oracledb://ETL_Automation:ETL_Automation@localhost:152/xe")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[20], line 13
#       4 oracledb.init_oracle_client(lib_dir=r"C:\oraclexe\app\oracle\instantclient_19_29")
#       5 # Connect to Oracle Database
#       6
#       7 #connection = oracledb.connect(
#    (...)
#      10 # dsn="localhost:1521/xe"
#      11 #)
# ---> 13 oracle_engine = create_engine("oracle+oracledb://ETL_Automation:ETL_Automation@localhost:152/xe", thick_mode=True)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File C:\Pycharm_Projects\pythonProject\.venv\lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
# ...

# %%
query = """select * from customer"""

# %%
df = pd.read_sql(query,oracle_engine)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# File C:\Pycharm_Projects\pythonProject\.venv\lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File C:\Pycharm_Projects\pythonProject\.venv\lib\site-packages\sqlalchemy\engine\base.py:3301, in Engine.raw_connection(self)
#    3280 """Return a "raw" DBAPI connection from the connection pool.
#    3281
#    3282 The returned object is a proxied version of the DBAPI
#    (...)
#    3299
#    3300 """
# -> 3301 return self.pool.connect()
#
# File C:\Pycharm_Projects\pythonProject\.venv\lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
#     440 """Return a DBAPI connection from the pool.
# ...

# %%
df
# Out:
#    CUSTOMERID     NAME          PHONE
# 0        C001    Alice     1234567890
# 1        C002      Bob     9876543210
# 2        C003  Charlie   555-123-4567
# 3        C004    David   (222)3334444
# 4        C005     Emma     4445556666
# 5        C006    Frank   333-444-5555
# 6        C007    Grace     8887776666
# 7        C008   Hannah     1112223333
# 8        C009      Ian  (999)888-7777
# 9        C010     Jack     7654321000
# 10       C011    Karen   555-666-7777
# 11       C012      Leo     2223334444
# 12       C013      Mia     1113335555
# 13       C014     Noah   123-456-7890
# 14       C015   Olivia  (321)654-0987

# %%
import oracledb
import pandas as pd
from sqlalchemy import create_engine

oracledb.init_oracle_client(lib_dir=r"C:\oraclexe\app\oracle\instantclient_19_29")

# %%
engine = create_engine(
    "oracle+oracledb://ETL_Automation:ETL_Automation@localhost:1521/xe"
)

# %%
# 3. Query test
query = """SELECT * FROM customer where customerid in ('C001','C002')"""

# %%
df = pd.read_sql(query,engine)

# %%
df
engine.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 2
#       1 df
# ----> 2 engine.close()
#
# AttributeError: 'Engine' object has no attribute 'close'

# %%
#Write result into database
df.to_sql('customers_updated',con = engine,index = False)
# Out:
# -1

# %%
import pandas as pd
import pyodbc
from sqlalchemy import create_engine

# %%
con_engine = (
    "mssql+pyodbc://LAPTOP-R3E5KI54\SQLEXPRESS/HR?"
    #"driver = ODBC+Driver+17+for+SQL+Server&trusted_connection =yes"
    "driver=ODBC+Driver+17+for+SQL+Server"
)

# %%
engine = create_engine(con_engine)

# %%
query_sql = """ select * from departments"""

# %%
df_department = pd.read_sql(query_sql, engine)

# %%
df_sql
# Out:
#     department_id   department_name  location_id
# 0               1    Administration         1700
# 1               2         Marketing         1800
# 2               3        Purchasing         1700
# 3               4   Human Resources         2400
# 4               5          Shipping         1500
# 5               6                IT         1400
# 6               7  Public Relations         2700
# 7               8             Sales         2500
# 8               9         Executive         1700
# 9              10           Finance         1700
# 10             11        Accounting         1700

# %%
con_engine.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 con_engine.close()
#
# AttributeError: 'str' object has no attribute 'close'

# %%
import oracledb
import pandas as pd

conn = oracledb.connect(
    user="ETL_Automation",
    password="ETL_Automation",
    dsn="localhost:1521/xe"
)

# %%
query = """SELECT * FROM customer where customerid in ('C001','C002','C005','C008')"""

# %%
result = pd.read_sql(query,conn)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7160\2900077234.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(query,conn)

# %%
result
# Out:
#   CUSTOMERID    NAME       PHONE
# 0       C001   Alice  1234567890
# 1       C002     Bob  9876543210
# 2       C005    Emma  4445556666
# 3       C008  Hannah  1112223333

# %%
conn.close()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 conn.close()
#
# File C:\Pycharm_Projects\pythonProject\.venv\lib\site-packages\oracledb\connection.py:1025, in Connection.close(self)
#    1009 def close(self) -> None:
#    1010     """
#    1011     Closes the connection now and makes it unusable for further operations.
#    1012     An Error exception will be raised if any operation is attempted with
#    (...)
#    1023     are available.
#    1024     """
# -> 1025     self._verify_connected()
#    1026     self._close()
#
# File C:\Pycharm_Projects\pythonProject\.venv\lib\site-packages\oracledb\connection.py:85, in BaseConnection._verify_connected(self)
#      80 """
#      81 Verifies that the connection is connected to the database. If it is
#      82 not, an exception is raised.
#      83 """
#      84 if self._impl is None:
# ...

# %%
import pandas as pd

# %%
df_emp = pd.read_csv('employees.csv')
df_dept = pd.read_csv('departments.csv')

# %%
df_join = df_emp.merge(df_dept,on='deptno',how='inner')

# %%
df_left = df_emp.merge(df_dept,on='deptno',how='left')

# %%
df_right = df_emp.merge(df_dept,on='deptno',how='right')

# %%
df_right
# Out:
#    eno   ename  deptno deptName
# 0  1.0    Ajay      10  Finance
# 1  2.0   Vijay      20       IT
# 2  3.0  Mahesh      30   Travel
# 3  NaN     NaN      80    Forex

# %%
df_full = df_emp.merge(df_dept,on='deptno',how='outer')

# %%
df_full
# Out:
#    eno   ename  deptno deptName
# 0  1.0    Ajay      10  Finance
# 1  2.0   Vijay      20       IT
# 2  3.0  Mahesh      30   Travel
# 3  4.0  Thomas      40      NaN
# 4  5.0  Robert      50      NaN
# 5  NaN     NaN      80    Forex

# %%
df_diff = pd.merge(df_emp,df_dept,on='deptno',how='left')

# %%
df_diff
# Out:
#    eno   ename  deptno deptName
# 0    1    Ajay      10  Finance
# 1    2   Vijay      20       IT
# 2    3  Mahesh      30   Travel
# 3    4  Thomas      40      NaN
# 4    5  Robert      50      NaN

# %%
df_dff = df_emp.merge(df_dept,left_on='deptno',right_on='deptno',how='right')

# %%
df_dff
# Out:
#    eno   ename  deptno deptName
# 0  1.0    Ajay      10  Finance
# 1  2.0   Vijay      20       IT
# 2  3.0  Mahesh      30   Travel
# 3  NaN     NaN      80    Forex
