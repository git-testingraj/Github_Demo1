# %%
import pandas as pd

# %%
df = pd.read_csv('emp.csv')

# %%
df_10 = df['deptno']==10

# %%
df_20 = df['deptno'] == 20

# %%
df_final = [df_10]&[df_20]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_final = [df_10]&[df_20]
#
# TypeError: unsupported operand type(s) for &: 'list' and 'list'

# %%
df_50 = df['salary'] > 2000

# %%
df_final = df_10 & df_50

# %%
df[df_final]
# Out:
# Empty DataFrame
# Columns: [eno, ename, salary, deptno, doj]
# Index: []

# %%
df[df_20]
# Out:
#     eno   ename  salary  deptno         doj
# 2     8   Sagar    1000      20  2020-11-30
# 6     7  Robert    3000      20  2023-06-25
# 11   12   Karan    2200      20  2018-06-16
# 14   15    Neha    1700      20  2021-07-22

# %%
df_emp = pd.read_csv('emp_details.csv')

# %%
df_emp
# Out:
#      eno               ename         doj  deptno  salary
# 0   1001        Arjun Sharma  2022-01-15      10    1000
# 1   1002         Priya Patel  2023-03-22      20   67387
# 2   1003          Ravi Kumar  2021-05-10      30   70421
# 3   1004         Sneha Gupta  2020-08-25      40   68902
# 4   1005          Anil Reddy  2024-02-13      50   78005
# 5   1006          Neha Verma  2019-11-30      60   59843
# 6   1007         Vijay Singh  2022-07-08      10    1000
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 8   1009        Manish Joshi  2020-12-19      30   67560
# 9   1010         Simran Kaur  2023-01-11      40   68902
# 10  1011        Rajesh Mehta  2021-09-01      50   62497
# 11  1012       Deepika Desai  2020-06-10      60   70179
# 12  1013      Shivani Sharma  2022-09-13      10   74363
# 13  1014         Harish Nair  2023-04-01      20   61487
# 14  1015         Komal Yadav  2021-11-23      30   61894
# ...

# %%
df_emp[(df_emp['deptno'] == 10) & (df_emp['salary'] > 50000)]
# Out:
#      eno           ename         doj  deptno  salary
# 12  1013  Shivani Sharma  2022-09-13      10   74363
# 20  1021  Prakash Pillai  2022-12-11      10   73569
# 26  1027   Harshit Kumar  2022-08-16      10   66535
# 32  1033     Suresh Jain  2021-12-01      10   69234
# 38  1039      Ajit Reddy  2022-04-18      10   69399
# 44  1045    Pankaj Joshi  2022-06-10      10   70445

# %%
df_emp[(df_emp['deptno'] == 10) | (df_emp['deptno'] == 20)]
# Out:
#      eno               ename         doj  deptno  salary
# 0   1001        Arjun Sharma  2022-01-15      10    1000
# 1   1002         Priya Patel  2023-03-22      20   67387
# 6   1007         Vijay Singh  2022-07-08      10    1000
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 12  1013      Shivani Sharma  2022-09-13      10   74363
# 13  1014         Harish Nair  2023-04-01      20   61487
# 18  1019          Meera Nair  2020-09-17      10    1000
# 19  1020         Krishna Rao  2023-10-02      20    2000
# 20  1021      Prakash Pillai  2022-12-11      10   73569
# 21  1022  Aishwarya Deshmukh  2021-07-25      20   69746
# 26  1027       Harshit Kumar  2022-08-16      10   66535
# 27  1028       Kanika Thakur  2020-01-10      20   67752
# 32  1033         Suresh Jain  2021-12-01      10   69234
# 33  1034          Sonal Shah  2023-08-13      20    2000
# 38  1039          Ajit Reddy  2022-04-18      10   69399
# ...

# %%
df_10 = df_emp['deptno'] == 10

# %%
df_20 = df_emp['deptno'] == 20

# %%
df_10_20 = df_10 | df_20

# %%
df_emp[df_10_20]
# Out:
#      eno               ename         doj  deptno  salary
# 0   1001        Arjun Sharma  2022-01-15      10    1000
# 1   1002         Priya Patel  2023-03-22      20   67387
# 6   1007         Vijay Singh  2022-07-08      10    1000
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 12  1013      Shivani Sharma  2022-09-13      10   74363
# 13  1014         Harish Nair  2023-04-01      20   61487
# 18  1019          Meera Nair  2020-09-17      10    1000
# 19  1020         Krishna Rao  2023-10-02      20    2000
# 20  1021      Prakash Pillai  2022-12-11      10   73569
# 21  1022  Aishwarya Deshmukh  2021-07-25      20   69746
# 26  1027       Harshit Kumar  2022-08-16      10   66535
# 27  1028       Kanika Thakur  2020-01-10      20   67752
# 32  1033         Suresh Jain  2021-12-01      10   69234
# 33  1034          Sonal Shah  2023-08-13      20    2000
# 38  1039          Ajit Reddy  2022-04-18      10   69399
# ...

# %%
df_not_10 = df_emp['deptno'] !=10

# %%
df_emp[df_not_10]
# Out:
#      eno               ename         doj  deptno  salary
# 1   1002         Priya Patel  2023-03-22      20   67387
# 2   1003          Ravi Kumar  2021-05-10      30   70421
# 3   1004         Sneha Gupta  2020-08-25      40   68902
# 4   1005          Anil Reddy  2024-02-13      50   78005
# 5   1006          Neha Verma  2019-11-30      60   59843
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 8   1009        Manish Joshi  2020-12-19      30   67560
# 9   1010         Simran Kaur  2023-01-11      40   68902
# 10  1011        Rajesh Mehta  2021-09-01      50   62497
# 11  1012       Deepika Desai  2020-06-10      60   70179
# 13  1014         Harish Nair  2023-04-01      20   61487
# 14  1015         Komal Yadav  2021-11-23      30   61894
# 15  1016          Ajay Bhatt  2020-04-25      40   70109
# 16  1017         Pooja Malik  2022-02-28      50   77450
# 17  1018        Raghav Joshi  2021-06-14      60   62873
# ...

# %%
df_emp[~df_10]
# Out:
#      eno               ename         doj  deptno  salary
# 1   1002         Priya Patel  2023-03-22      20   67387
# 2   1003          Ravi Kumar  2021-05-10      30   70421
# 3   1004         Sneha Gupta  2020-08-25      40   68902
# 4   1005          Anil Reddy  2024-02-13      50   78005
# 5   1006          Neha Verma  2019-11-30      60   59843
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 8   1009        Manish Joshi  2020-12-19      30   67560
# 9   1010         Simran Kaur  2023-01-11      40   68902
# 10  1011        Rajesh Mehta  2021-09-01      50   62497
# 11  1012       Deepika Desai  2020-06-10      60   70179
# 13  1014         Harish Nair  2023-04-01      20   61487
# 14  1015         Komal Yadav  2021-11-23      30   61894
# 15  1016          Ajay Bhatt  2020-04-25      40   70109
# 16  1017         Pooja Malik  2022-02-28      50   77450
# 17  1018        Raghav Joshi  2021-06-14      60   62873
# ...

# %%
dept_10 = df_emp['deptno'] == 10
dept_20 = df_emp['deptno'] == 20
sal_50 = df_emp['salary'] >50000

# %%
df_10_20_50 = dept_10 | dept_20 & sal_50

# %%
df_emp[df_10_20_50]
# Out:
#      eno               ename         doj  deptno  salary
# 0   1001        Arjun Sharma  2022-01-15      10    1000
# 1   1002         Priya Patel  2023-03-22      20   67387
# 6   1007         Vijay Singh  2022-07-08      10    1000
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 12  1013      Shivani Sharma  2022-09-13      10   74363
# 13  1014         Harish Nair  2023-04-01      20   61487
# 18  1019          Meera Nair  2020-09-17      10    1000
# 20  1021      Prakash Pillai  2022-12-11      10   73569
# 21  1022  Aishwarya Deshmukh  2021-07-25      20   69746
# 26  1027       Harshit Kumar  2022-08-16      10   66535
# 27  1028       Kanika Thakur  2020-01-10      20   67752
# 32  1033         Suresh Jain  2021-12-01      10   69234
# 38  1039          Ajit Reddy  2022-04-18      10   69399
# 39  1040     Pratibha Sharma  2021-09-05      20   65072
# 44  1045        Pankaj Joshi  2022-06-10      10   70445
# ...

# %%
df_emp.sort_values(by ='salary', ascending = False)
# Out:
#      eno               ename         doj  deptno  salary
# 4   1005          Anil Reddy  2024-02-13      50   78005
# 16  1017         Pooja Malik  2022-02-28      50   77450
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 12  1013      Shivani Sharma  2022-09-13      10   74363
# 20  1021      Prakash Pillai  2022-12-11      10   73569
# 36  1037      Rajendra Joshi  2023-11-19      50   73561
# 30  1031        Akash Prasad  2020-06-05      50   72594
# 41  1042        Sunita Gupta  2023-03-09      40   72534
# 37  1038        Kavita Mehta  2020-07-25      60   71892
# 28  1029      Arvind Agarwal  2023-02-18      30   70986
# 44  1045        Pankaj Joshi  2022-06-10      10   70445
# 2   1003          Ravi Kumar  2021-05-10      30   70421
# 11  1012       Deepika Desai  2020-06-10      60   70179
# 15  1016          Ajay Bhatt  2020-04-25      40   70109
# 42  1043        Arvind Kumar  2021-08-22      50   70019
# ...

# %%
df_sort
# Out:
#      eno               ename         doj  deptno  salary
# 4   1005          Anil Reddy  2024-02-13      50   78005
# 16  1017         Pooja Malik  2022-02-28      50   77450
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 12  1013      Shivani Sharma  2022-09-13      10   74363
# 20  1021      Prakash Pillai  2022-12-11      10   73569
# 36  1037      Rajendra Joshi  2023-11-19      50   73561
# 30  1031        Akash Prasad  2020-06-05      50   72594
# 41  1042        Sunita Gupta  2023-03-09      40   72534
# 37  1038        Kavita Mehta  2020-07-25      60   71892
# 28  1029      Arvind Agarwal  2023-02-18      30   70986
# 44  1045        Pankaj Joshi  2022-06-10      10   70445
# 2   1003          Ravi Kumar  2021-05-10      30   70421
# 11  1012       Deepika Desai  2020-06-10      60   70179
# 15  1016          Ajay Bhatt  2020-04-25      40   70109
# 42  1043        Arvind Kumar  2021-08-22      50   70019
# ...

# %%
df_emp.sort_values(by = ['salary','deptno'], ascending = [False,True],inplace = True)

# %%
df_emp
# Out:
#      eno               ename         doj  deptno  salary
# 4   1005          Anil Reddy  2024-02-13      50   78005
# 16  1017         Pooja Malik  2022-02-28      50   77450
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 12  1013      Shivani Sharma  2022-09-13      10   74363
# 20  1021      Prakash Pillai  2022-12-11      10   73569
# 36  1037      Rajendra Joshi  2023-11-19      50   73561
# 30  1031        Akash Prasad  2020-06-05      50   72594
# 41  1042        Sunita Gupta  2023-03-09      40   72534
# 37  1038        Kavita Mehta  2020-07-25      60   71892
# 28  1029      Arvind Agarwal  2023-02-18      30   70986
# 44  1045        Pankaj Joshi  2022-06-10      10   70445
# 2   1003          Ravi Kumar  2021-05-10      30   70421
# 11  1012       Deepika Desai  2020-06-10      60   70179
# 15  1016          Ajay Bhatt  2020-04-25      40   70109
# 42  1043        Arvind Kumar  2021-08-22      50   70019
# ...

# %%
df_total = df_emp.groupby('deptno')['salary'].sum().reset_index().rename(columns = {'salary':'total_sal'})

# %%
df_total
# Out:
#    deptno  total_sal
# 0      10     426545
# 1      20     477820
# 2      30     536809
# 3      40     545880
# 4      50     570135
# 5      60     525908

# %%
df_emp.sort_values(by =['salary','deptno'],ascending = [True, False],inplace = True)

# %%
df_emp
# Out:
#      eno               ename         doj  deptno  salary
# 0   1001        Arjun Sharma  2022-01-15      10    1000
# 6   1007         Vijay Singh  2022-07-08      10    1000
# 18  1019          Meera Nair  2020-09-17      10    1000
# 19  1020         Krishna Rao  2023-10-02      20    2000
# 33  1034          Sonal Shah  2023-08-13      20    2000
# 5   1006          Neha Verma  2019-11-30      60   59843
# 49  1050       Sandeep Yadav  2021-10-12      60   60921
# 22  1023          Vikas Soni  2020-11-15      30   60933
# 13  1014         Harish Nair  2023-04-01      20   61487
# 14  1015         Komal Yadav  2021-11-23      30   61894
# 10  1011        Rajesh Mehta  2021-09-01      50   62497
# 17  1018        Raghav Joshi  2021-06-14      60   62873
# 35  1036        Shweta Yadav  2021-06-03      40   63559
# 31  1032          Geeta Rani  2022-09-07      60   63916
# 39  1040     Pratibha Sharma  2021-09-05      20   65072
# ...

# %%
df_count = df_emp.groupby('deptno')['ename'].count().reset_index().rename(columns = {'ename':'emp_count'})

# %%
df_count
# Out:
#    deptno  emp_count
# 0      10          9
# 1      20          9
# 2      30          8
# 3      40          8
# 4      50          8
# 5      60          8

# %%
df_sal = df_emp['salary'] < 50000

# %%
df_group = df_emp[df_sal].groupby('deptno')['salary'].sum().reset_index().rename(columns = {'salary':'total_sal'})

# %%
df_group
# Out:
#    deptno  total_sal
# 0      10       3000
# 1      20       4000

# %%
df_emp[df_sal]
# Out:
#      eno         ename         doj  deptno  salary
# 0   1001  Arjun Sharma  2022-01-15      10    1000
# 6   1007   Vijay Singh  2022-07-08      10    1000
# 18  1019    Meera Nair  2020-09-17      10    1000
# 19  1020   Krishna Rao  2023-10-02      20    2000
# 33  1034    Sonal Shah  2023-08-13      20    2000

# %%
df_emp.groupby(['deptno','salary'])['ename'].count().reset_index()
# Out:
#     deptno  salary  ename
# 0       10    1000      3
# 1       10   66535      1
# 2       10   69234      1
# 3       10   69399      1
# 4       10   70445      1
# 5       10   73569      1
# 6       10   74363      1
# 7       20    2000      2
# 8       20   61487      1
# 9       20   65072      1
# 10      20   67387      1
# 11      20   67751      1
# 12      20   67752      1
# 13      20   69746      1
# 14      20   74625      1
# 15      30   60933      1
# 16      30   61894      1
# 17      30   66989      1
# 18      30   67560      1
# 19      30   68215      1
# 20      30   69811      1
# 21      30   70421      1
# 22      30   70986      1
# 23      40   63559      1
# 24      40   66228      1
# 25      40   67801      1
# 26      40   67845      1
# 27      40   68902      2
# 28      40   70109      1
# 29      40   72534      1
# 30      50   62497      1
# 31      50   66948      1
# 32      50   69061      1
# 33      50   70019      1
# ...

# %%
df_emp.groupby('deptno').agg(['count','sum','max',''])
