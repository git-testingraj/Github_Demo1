# %%
import pandas as pd
import pyodbc

# %%
conn = pyodbc.connect(
    "Driver={ODBC Driver 17 for SQL Server};"
    "Server=LAPTOP-R3E5KI54\SQLEXPRESS;"
    "Database=HR;"
    "Trusted_Connection=yes;"
)

# %%
cur = conn.cursor()
cur.execute('select * from employees')
rows = cursor.fetchall()
cur.commit()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[13], line 2
#       1 cur = conn.cursor()
# ----> 2 cur.execute('select * from employees')
#       3 rows = cursor.fetchall()
#       4 cur.commit()
#
# Error: ('HY000', '[HY000] [Microsoft][ODBC Driver 17 for SQL Server]Connection is busy with results for another command (0) (SQLExecDirectW)')

# %%
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'SQL Server Native Client 11.0', 'SQL Server Native Client RDA 11.0', 'ODBC Driver 17 for SQL Server', 'Oracle in XE', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)']
