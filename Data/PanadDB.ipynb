# %%
import pandas as pd
import pyodbc
from sqlalchemy import create_engine

# %%
database_connection = (
    "mssql+pyodbc://LAPTOP-R3E5KI54\SQLEXPRESS/HR?"
    "driver=ODBC+Driver+17+for+SQL+Server"
)

# %%
engine = create_engine(database_connection)

# %%
query = """select employee_id,first_name,department_name,email,hire_date,salary from employees e join departments d on e.department_id = d.department_id"""

# %%
df = pd.read_sql(query,engine)

# %%
df
# Out:
#     employee_id   first_name   department_name  \
# 0           100       Steven         Executive
# 1           101        Neena         Executive
# 2           102          Lex         Executive
# 3           103    Alexander                IT
# 4           104        Bruce                IT
# 5           105        David                IT
# 6           106        Valli                IT
# 7           107        Diana                IT
# 8           108        Nancy           Finance
# 9           109       Daniel           Finance
# 10          110         John           Finance
# 11          111       Ismael           Finance
# 12          112  Jose Manuel           Finance
# 13          113         Luis           Finance
# 14          114          Den        Purchasing
# 15          115    Alexander        Purchasing
# 16          116       Shelli        Purchasing
# 17          117        Sigal        Purchasing
# 18          118          Guy        Purchasing
# ...

# %%
import pandas as pd
import oracledb
from sqlalchemy import create_engine

# %%
oracledb.init_oracle_client(lib_dir=r"C:\oraclexe\app\oracle\instantclient_19_29")

# %%
DB_Connection = create_engine("oracle+oracledb://ETL_Automation:ETL_Automation@localhost:1521/xe")

# %%
query = """select * from customer"""

# %%
query_1 = """select * from products"""

# %%
df_oracle = pd.read_sql(query,DB_Connection)

# %%
df_oracle.to_parquet('Products_parquet.parquet', engine = 'pyarrow',index = False)

# %%
oracle_par = pd.read_parquet('Products_parquet.parquet')

# %%
df_sort = df_oracle.sort_values(by ='customerid',ascending = False)

# %%
df_sort
# Out:
#    customerid     name          phone
# 14       C015   Olivia  (321)654-0987
# 13       C014     Noah   123-456-7890
# 12       C013      Mia     1113335555
# 11       C012      Leo     2223334444
# 10       C011    Karen   555-666-7777
# 9        C010     Jack     7654321000
# 8        C009      Ian  (999)888-7777
# 7        C008   Hannah     1112223333
# 6        C007    Grace     8887776666
# 5        C006    Frank   333-444-5555
# 4        C005     Emma     4445556666
# 3        C004    David   (222)3334444
# 2        C003  Charlie   555-123-4567
# 1        C002      Bob     9876543210
# 0        C001    Alice     1234567890

# %%
df_sort1 = df.sort_values(by=['salary','employee_id'],ascending = [True,False])

# %%
df_sort1
# Out:
#     employee_id   first_name   department_name  \
# 19          119        Karen        Purchasing
# 18          118          Guy        Purchasing
# 24          126        Irene          Shipping
# 17          117        Sigal        Purchasing
# 16          116       Shelli        Purchasing
# 15          115    Alexander        Purchasing
# 32          193      Britney          Shipping
# 31          192     Abhishek          Shipping
# 7           107        Diana                IT
# 33          200     Jennifer    Administration
# 6           106        Valli                IT
# 5           105        David                IT
# 35          202          Pat         Marketing
# 4           104        Bruce                IT
# 30          179      Charles             Sales
# 36          203        Susan   Human Resources
# 23          123       Shanta          Shipping
# 13          113         Luis           Finance
# 29          178    Kimberely             Sales
# ...

# %%
df_sort2 = df.sort_values(by='salary',ascending = True)

# %%
df_sort2
# Out:
#     employee_id   first_name   department_name  \
# 19          119        Karen        Purchasing
# 18          118          Guy        Purchasing
# 24          126        Irene          Shipping
# 17          117        Sigal        Purchasing
# 16          116       Shelli        Purchasing
# 15          115    Alexander        Purchasing
# 32          193      Britney          Shipping
# 31          192     Abhishek          Shipping
# 7           107        Diana                IT
# 33          200     Jennifer    Administration
# 6           106        Valli                IT
# 5           105        David                IT
# 4           104        Bruce                IT
# 35          202          Pat         Marketing
# 30          179      Charles             Sales
# 23          123       Shanta          Shipping
# 36          203        Susan   Human Resources
# 13          113         Luis           Finance
# 29          178    Kimberely             Sales
# ...

# %%
df_count_emp = df.groupby('department_name')['first_name'].count().reset_index()

# %%
df_count_emp.rename(columns = {'first_name':'emp_count'})
# Out:
#      department_name  emp_count
# 0         Accounting          2
# 1     Administration          1
# 2          Executive          3
# 3            Finance          6
# 4    Human Resources          1
# 5                 IT          5
# 6          Marketing          2
# 7   Public Relations          1
# 8         Purchasing          6
# 9              Sales          6
# 10          Shipping          7

# %%
df_dept_sal = df.groupby(['department_name','salary'])['first_name'].count().reset_index()

# %%
df_dept_sal.rename(columns = {'first_name':'emp_count'})
# Out:
#      department_name  salary  emp_count
# 0         Accounting    8300          1
# 1         Accounting   12000          1
# 2     Administration    4400          1
# 3          Executive   17000          2
# 4          Executive   24000          1
# 5            Finance    6900          1
# 6            Finance    7700          1
# 7            Finance    7800          1
# 8            Finance    8200          1
# 9            Finance    9000          1
# 10           Finance   12000          1
# 11   Human Resources    6500          1
# 12                IT    4200          1
# 13                IT    4800          2
# 14                IT    6000          1
# 15                IT    9000          1
# 16         Marketing    6000          1
# 17         Marketing   13000          1
# 18  Public Relations   10000          1
# 19        Purchasing    2500          1
# 20        Purchasing    2600          1
# 21        Purchasing    2800          1
# ...

# %%
df_agg_all = df.groupby('department_name')['salary'].agg(['count','sum','max','min']).reset_index()

# %%
col_name = {'count':'emp_count','sum':'emp_sum','max':'emp_max','min':'emp_min'}

# %%
df_agg_all.rename(columns = col_name)
# Out:
#      department_name  emp_count  emp_sum  emp_max  emp_min
# 0         Accounting          2    20300    12000     8300
# 1     Administration          1     4400     4400     4400
# 2          Executive          3    58000    24000    17000
# 3            Finance          6    51600    12000     6900
# 4    Human Resources          1     6500     6500     6500
# 5                 IT          5    28800     9000     4200
# 6          Marketing          2    19000    13000     6000
# 7   Public Relations          1    10000    10000    10000
# 8         Purchasing          6    24900    11000     2500
# 9              Sales          6    57700    14000     6200
# 10          Shipping          7    41200     8200     2700

# %%
df_sal = df['salary'] <=10000

# %%
df_grouped = df[df_sal].groupby('department_name')['salary'].sum().reset_index().rename(columns = {'salary':'sum_sal'})

# %%
df_grouped
# Out:
#     department_name  sum_sal
# 0        Accounting     8300
# 1    Administration     4400
# 2           Finance    39600
# 3   Human Resources     6500
# 4                IT    28800
# 5         Marketing     6000
# 6  Public Relations    10000
# 7        Purchasing    13900
# 8             Sales    30200
# 9          Shipping    41200

# %%
df_groupp = df.groupby('department_name')['salary'].sum()

# %%
df_hav = df_groupp.apply(lambda x:x<10000)

# %%
df_res = df_groupp[df_hav].reset_index()

# %%
df_res
# Out:
#    department_name  salary
# 0   Administration    4400
# 1  Human Resources    6500
